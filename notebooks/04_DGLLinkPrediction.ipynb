# %% [markdown]
# ### Link prediction to predict if there is an edge of a certain type between a pair of nodes
#
# References:
# - https://github.com/dmlc/dgl/tree/master/examples/pytorch/rgcn
# - https://arxiv.org/abs/1703.06103

# %%
import dgl
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from dgl.contrib.data import load_data
from dgl.nn.pytorch import RelGraphConv
import time

# %%
class EmbeddingLayer(nn.Module):
    def __init__(self, num_nodes, h_dim):
        super(EmbeddingLayer, self).__init__()
        self.embedding = torch.nn.Embedding(num_nodes, h_dim)

    def forward(self, g, h, r, norm):
        return self.embedding(h.squeeze())

# %%
class BaseRGCN(nn.Module):
    def __init__(self, num_nodes, h_dim, out_dim, num_rels, num_bases,
                 num_hidden_layers=1, dropout=0,
                 use_self_loop=False, use_cuda=False):
        super(BaseRGCN, self).__init__()
        self.num_nodes = num_nodes
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.num_rels = num_rels
        self.num_bases = None if num_bases < 0 else num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_self_loop = use_self_loop
        self.use_cuda = use_cuda

        # create rgcn layers
        self.build_model()

    def build_model(self):
        self.layers = nn.ModuleList()
        # i2h
        i2h = self.build_input_layer()
        if i2h is not None:
            self.layers.append(i2h)
        # h2h
        for idx in range(self.num_hidden_layers):
            h2h = self.build_hidden_layer(idx)
            self.layers.append(h2h)
        # h2o
        h2o = self.build_output_layer()
        if h2o is not None:
            self.layers.append(h2o)

    def build_input_layer(self):
        return None

    def build_hidden_layer(self, idx):
        raise NotImplementedError

    def build_output_layer(self):
        return None

    def forward(self, g, h, r, norm):
        for layer in self.layers:
            h = layer(g, h, r, norm)
        return h

# %%
class RGCN(BaseRGCN):
    def build_input_layer(self):
        return EmbeddingLayer(self.num_nodes, self.h_dim)

    def build_hidden_layer(self, idx):
        act = F.relu if idx < self.num_hidden_layers - 1 else None
        return RelGraphConv(self.h_dim, self.h_dim, self.num_rels, "bdd",
                self.num_bases, activation=act, self_loop=True,
                dropout=self.dropout)

# %%
class LinkPredict(nn.Module):
    def __init__(self, in_dim, h_dim, num_rels, num_bases=-1,
                 num_hidden_layers=1, dropout=0, use_cuda=False, reg_param=0):
        super(LinkPredict, self).__init__()
        self.rgcn = RGCN(in_dim, h_dim, h_dim, num_rels * 2, num_bases,
                         num_hidden_layers, dropout, use_cuda)
        self.reg_param = reg_param
        self.w_relation = nn.Parameter(torch.Tensor(num_rels, h_dim))
        nn.init.xavier_uniform_(self.w_relation,
                                gain=nn.init.calculate_gain('relu'))

    def calc_score(self, embedding, triplets):
        # DistMult
        s = embedding[triplets[:,0]]
        r = self.w_relation[triplets[:,1]]
        o = embedding[triplets[:,2]]
        score = torch.sum(s * r * o, dim=1)
        return score

    def forward(self, g, h, r, norm):
        return self.rgcn.forward(g, h, r, norm)

    def regularization_loss(self, embedding):
        return torch.mean(embedding.pow(2)) + torch.mean(self.w_relation.pow(2))

    def get_loss(self, g, embed, triplets, labels):
        # triplets is a list of data samples (positive and negative)
        # each row in the triplets is a 3-tuple of (source, relation, destination)
        score = self.calc_score(embed, triplets)
        predict_loss = F.binary_cross_entropy_with_logits(score, labels)
        reg_loss = self.regularization_loss(embed)
        return predict_loss + self.reg_param * reg_loss

# %%
def node_norm_to_edge_norm(g, node_norm):
    g = g.local_var()
    # convert to edge norm
    g.ndata['norm'] = node_norm
    g.apply_edges(lambda edges : {'norm' : edges.dst['norm']})
    return g.edata['norm']

# %%
data = load_data('FB15k')
# Out:
# # entities: 14951
# # relations: 1345
# # edges: 483142

# %%
num_nodes = data.num_nodes
train_data = data.train
valid_data = data.valid
test_data = data.test
num_rels = data.num_rels

# %%
dropout=0.2
n_hidden=100
gpu=-1
lr=1e-2
n_bases=100
n_layers=2
n_epochs=200
dataset='FB15k'
eval_batch_size=500
eval_protocol="filtered"
regularization=0.01
grad_norm=1.0
graph_batch_size=3000
graph_split_size=0.5
negative_sample=10
evaluate_every=500
edge_sampler="uniform"

# %%
use_cuda = torch.cuda.is_available()

if use_cuda:
    torch.cuda.set_device(0)

model = LinkPredict(num_nodes,
                    n_hidden,
                    num_rels,
                    num_bases=n_bases,
                    num_hidden_layers=n_layers,
                    dropout=dropout,
                    use_cuda=use_cuda,
                    reg_param=regularization)

# %%
valid_data = torch.LongTensor(valid_data)
test_data = torch.LongTensor(test_data)

# %%
def comp_deg_norm(g):
    g = g.local_var()
    in_deg = g.in_degrees(range(g.number_of_nodes())).float().numpy()
    norm = 1.0 / in_deg
    norm[np.isinf(norm)] = 0
    return norm

def build_graph_from_triplets(num_nodes, num_rels, triplets):
    g = dgl.DGLGraph()
    g.add_nodes(num_nodes)
    src, rel, dst = triplets
    src, dst = np.concatenate((src, dst)), np.concatenate((dst, src))
    rel = np.concatenate((rel, rel + num_rels))
    edges = sorted(zip(dst, src, rel))
    dst, src, rel = np.array(edges).transpose()
    g.add_edges(src, dst)
    norm = comp_deg_norm(g)
    print("# nodes: {}, # edges: {}".format(num_nodes, len(src)))
    return g, rel.astype('int64'), norm.astype('int64')

def build_test_graph(num_nodes, num_rels, edges):
    src, rel, dst = edges.transpose()
    print("Test graph:")
    return build_graph_from_triplets(num_nodes, num_rels, (src, rel, dst))

def get_adj_and_degrees(num_nodes, triplets):
    adj_list = [[] for _ in range(num_nodes)]
    for i,triplet in enumerate(triplets):
        adj_list[triplet[0]].append([i, triplet[2]])
        adj_list[triplet[2]].append([i, triplet[0]])

    degrees = np.array([len(a) for a in adj_list])
    adj_list = [np.array(a) for a in adj_list]
    return adj_list, degrees

def node_norm_to_edge_norm(g, node_norm):
    g = g.local_var()
    g.ndata['norm'] = node_norm
    g.apply_edges(lambda edges : {'norm' : edges.dst['norm']})
    return g.edata['norm']

# %%
test_graph, test_rel, test_norm = build_test_graph(num_nodes, num_rels, train_data)
test_deg = test_graph.in_degrees(
            range(test_graph.number_of_nodes())).float().view(-1,1)
test_node_id = torch.arange(0, num_nodes, dtype=torch.long).view(-1, 1)
test_rel = torch.from_numpy(test_rel)
test_norm = node_norm_to_edge_norm(test_graph, torch.from_numpy(test_norm).view(-1, 1))
if use_cuda:
    model.cuda()
# Out:
# Test graph:
# # nodes: 14951, # edges: 966284

# %%
def generate_sampled_graph_and_labels(triplets, sample_size, split_size,
                                      num_rels, adj_list, degrees,
                                      negative_rate, sampler="uniform"):
    if sampler == "uniform":
        edges = sample_edge_uniform(adj_list, degrees, len(triplets), sample_size)
    elif sampler == "neighbor":
        edges = sample_edge_neighborhood(adj_list, degrees, len(triplets), sample_size)
    else:
        raise ValueError("Sampler type must be either 'uniform' or 'neighbor'.")

    edges = triplets[edges]
    src, rel, dst = edges.transpose()
    uniq_v, edges = np.unique((src, dst), return_inverse=True)
    src, dst = np.reshape(edges, (2, -1))
    relabeled_edges = np.stack((src, rel, dst)).transpose()

    samples, labels = negative_sampling(relabeled_edges, len(uniq_v),
                                        negative_rate)
    split_size = int(sample_size * split_size)
    graph_split_ids = np.random.choice(np.arange(sample_size),
                                       size=split_size, replace=False)
    src = src[graph_split_ids]
    dst = dst[graph_split_ids]
    rel = rel[graph_split_ids]

    print("# sampled nodes: {}".format(len(uniq_v)))
    print("# sampled edges: {}".format(len(src) * 2))
    g, rel, norm = build_graph_from_triplets(len(uniq_v), num_rels,
                                             (src, rel, dst))
    return g, uniq_v, rel, norm, samples, labels

def sample_edge_uniform(adj_list, degrees, n_triplets, sample_size):
    """Sample edges uniformly from all the edges."""
    all_edges = np.arange(n_triplets)
    return np.random.choice(all_edges, sample_size, replace=False)

def negative_sampling(pos_samples, num_entity, negative_rate):
    size_of_batch = len(pos_samples)
    num_to_generate = size_of_batch * negative_rate
    neg_samples = np.tile(pos_samples, (negative_rate, 1))
    labels = np.zeros(size_of_batch * (negative_rate + 1), dtype=np.float32)
    labels[: size_of_batch] = 1
    values = np.random.randint(num_entity, size=num_to_generate)
    choices = np.random.uniform(size=num_to_generate)
    subj = choices > 0.5
    obj = choices <= 0.5
    neg_samples[subj, 0] = values[subj]
    neg_samples[obj, 2] = values[obj]

    return np.concatenate((pos_samples, neg_samples)), labels

def calc_filtered_mrr(embedding, w, train_triplets, valid_triplets, test_triplets, hits=[]):
    with torch.no_grad():
        s = test_triplets[:, 0]
        r = test_triplets[:, 1]
        o = test_triplets[:, 2]
        test_size = test_triplets.shape[0]

        triplets_to_filter = torch.cat([train_triplets, valid_triplets, test_triplets]).tolist()
        triplets_to_filter = {tuple(triplet) for triplet in triplets_to_filter}
        print('Perturbing subject...')
        ranks_s = perturb_s_and_get_filtered_rank(embedding, w, s, r, o, test_size, triplets_to_filter)
        print('Perturbing object...')
        ranks_o = perturb_o_and_get_filtered_rank(embedding, w, s, r, o, test_size, triplets_to_filter)

        ranks = torch.cat([ranks_s, ranks_o])
        ranks += 1

        mrr = torch.mean(1.0 / ranks.float())
        print("MRR (filtered): {:.6f}".format(mrr.item()))

        for hit in hits:
            avg_count = torch.mean((ranks <= hit).float())
            print("Hits (filtered) @ {}: {:.6f}".format(hit, avg_count.item()))
    return mrr.item()

def perturb_o_and_get_filtered_rank(embedding, w, s, r, o, test_size, triplets_to_filter):
    """ Perturb object in the triplets
    """
    num_entities = embedding.shape[0]
    ranks = []
    for idx in range(test_size):
        if idx % 100 == 0:
            print("test triplet {} / {}".format(idx, test_size))
        target_s = s[idx]
        target_r = r[idx]
        target_o = o[idx]
        filtered_o = filter_o(triplets_to_filter, target_s, target_r, target_o, num_entities)
        target_o_idx = int((filtered_o == target_o).nonzero())
        emb_s = embedding[target_s]
        emb_r = w[target_r]
        emb_o = embedding[filtered_o]
        emb_triplet = emb_s * emb_r * emb_o
        scores = torch.sigmoid(torch.sum(emb_triplet, dim=1))
        _, indices = torch.sort(scores, descending=True)
        rank = int((indices == target_o_idx).nonzero())
        ranks.append(rank)
    return torch.LongTensor(ranks)

def perturb_s_and_get_filtered_rank(embedding, w, s, r, o, test_size, triplets_to_filter):
    """ Perturb subject in the triplets
    """
    num_entities = embedding.shape[0]
    ranks = []
    for idx in range(test_size):
        if idx % 100 == 0:
            print("test triplet {} / {}".format(idx, test_size))
        target_s = s[idx]
        target_r = r[idx]
        target_o = o[idx]
        filtered_s = filter_s(triplets_to_filter, target_s, target_r, target_o, num_entities)
        target_s_idx = int((filtered_s == target_s).nonzero())
        emb_s = embedding[filtered_s]
        emb_r = w[target_r]
        emb_o = embedding[target_o]
        emb_triplet = emb_s * emb_r * emb_o
        scores = torch.sigmoid(torch.sum(emb_triplet, dim=1))
        _, indices = torch.sort(scores, descending=True)
        rank = int((indices == target_s_idx).nonzero())
        ranks.append(rank)
    return torch.LongTensor(ranks)

def filter_s(triplets_to_filter, target_s, target_r, target_o, num_entities):
    target_s, target_r, target_o = int(target_s), int(target_r), int(target_o)
    filtered_s = []
    # Do not filter out the test triplet, since we want to predict on it
    if (target_s, target_r, target_o) in triplets_to_filter:
        triplets_to_filter.remove((target_s, target_r, target_o))
    # Do not consider a subject if it is part of a triplet to filter
    for s in range(num_entities):
        if (s, target_r, target_o) not in triplets_to_filter:
            filtered_s.append(s)
    return torch.LongTensor(filtered_s)

def filter_o(triplets_to_filter, target_s, target_r, target_o, num_entities):
    target_s, target_r, target_o = int(target_s), int(target_r), int(target_o)
    filtered_o = []
    # Do not filter out the test triplet, since we want to predict on it
    if (target_s, target_r, target_o) in triplets_to_filter:
        triplets_to_filter.remove((target_s, target_r, target_o))
    # Do not consider an object if it is part of a triplet to filter
    for o in range(num_entities):
        if (target_s, target_r, o) not in triplets_to_filter:
            filtered_o.append(o)
    return torch.LongTensor(filtered_o)

def calc_mrr(embedding, w, train_triplets, valid_triplets, test_triplets, hits=[], eval_bz=100, eval_p="filtered"):
    if eval_p == "filtered":
        mrr = calc_filtered_mrr(embedding, w, train_triplets, valid_triplets, test_triplets, hits)
    else:
        mrr = calc_raw_mrr(embedding, w, test_triplets, hits, eval_bz)
    return mrr

# %%
adj_list, degrees = get_adj_and_degrees(num_nodes, train_data)

optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
model_state_file = 'model_state.pth'
forward_time = []
backward_time = []

print("start training...")

epoch = 0
best_mrr = 0
while True:
    model.train()
    epoch += 1

    g, node_id, edge_type, node_norm, data, labels = \
        generate_sampled_graph_and_labels(
            train_data, graph_batch_size, graph_split_size,
            num_rels, adj_list, degrees, negative_sample,
            edge_sampler)
    print("Done edge sampling")

    node_id = torch.from_numpy(node_id).view(-1, 1).long()
    edge_type = torch.from_numpy(edge_type)
    edge_norm = node_norm_to_edge_norm(g, torch.from_numpy(node_norm).view(-1, 1))
    data, labels = torch.from_numpy(data), torch.from_numpy(labels)
    deg = g.in_degrees(range(g.number_of_nodes())).float().view(-1, 1)

    if use_cuda:
        node_id, deg = node_id.cuda(), deg.cuda()
        edge_type, edge_norm = edge_type.cuda(), edge_norm.cuda()
        data, labels = data.cuda(), labels.cuda()

    t0 = time.time()
    embed = model(g, node_id, edge_type, edge_norm)
    loss = model.get_loss(g, embed, data, labels)
    t1 = time.time()
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), grad_norm) # clip gradients
    optimizer.step()
    t2 = time.time()

    forward_time.append(t1 - t0)
    backward_time.append(t2 - t1)
    print("Epoch {:04d} | Loss {:.4f} | Best MRR {:.4f} | Forward {:.4f}s | Backward {:.4f}s".
            format(epoch, loss.item(), best_mrr, forward_time[-1], backward_time[-1]))

    optimizer.zero_grad()

    if epoch % evaluate_every == 0:
        if use_cuda:
            model.cpu()
        model.eval()
        print("start eval")
        embed = model(test_graph, test_node_id, test_rel, test_norm)
        mrr = calc_mrr(embed, model.w_relation, torch.LongTensor(train_data),
                                valid_data, test_data, hits=[1, 3, 10], eval_bz=eval_batch_size,
                                eval_p=eval_protocol)
        if mrr < best_mrr:
            if epoch >= n_epochs:
                break
        else:
            best_mrr = mrr
            torch.save({'state_dict': model.state_dict(), 'epoch': epoch},
                        model_state_file)
        if use_cuda:
            model.cuda()

print("training done")
print("Mean forward time: {:4f}s".format(np.mean(forward_time)))
print("Mean Backward time: {:4f}s".format(np.mean(backward_time)))
# Out:
# 71
# test triplet 44500 / 59071
# test triplet 44600 / 59071
# test triplet 44700 / 59071
# test triplet 44800 / 59071
# test triplet 44900 / 59071
# test triplet 45000 / 59071
# test triplet 45100 / 59071
# test triplet 45200 / 59071
# test triplet 45300 / 59071
# test triplet 45400 / 59071
# test triplet 45500 / 59071
# test triplet 45600 / 59071
# test triplet 45700 / 59071
# test triplet 45800 / 59071
# test triplet 45900 / 59071
# test triplet 46000 / 59071
# test triplet 46100 / 59071
# test triplet 46200 / 59071
# test triplet 46300 / 59071
# test triplet 46400 / 59071
# test triplet 46500 / 59071
# test triplet 46600 / 59071
# test triplet 46700 / 59071
# test triplet 46800 / 59071
# test triplet 46900 / 59071
# test triplet 47000 / 59071
# test triplet 47100 / 59071
# test triplet 47200 / 59071
# test triplet 47300 / 59071
# test triplet 47400 / 59071
# test triplet 47500 / 59071
# test triplet 47600 / 59071
# test triplet 47700 / 59071
# test triplet 47800 / 59071
# test triplet 47900 / 59071
# test triplet 48000 / 59071
# test triplet 48100 / 59071
# test triplet 48200 / 59071
# test triplet 48300 / 59071
# test triplet 48400 / 59071
# test triplet 48500 / 59071
# test triplet 48600 / 59071
# test triplet 48700 / 59071
# test triplet 48800 / 59071
# test triplet 48900 / 59071
# test triplet 49000 / 59071
# test triplet 49100 / 59071
# test triplet 49200 / 59071
# test triplet 49300 / 59071
# test triplet 49400 / 59071
# test triplet 49500 / 59071
# test triplet 49600 / 59071
# test triplet 49700 / 59071
# test triplet 49800 / 59071
# test triplet 49900 / 59071
# test triplet 50000 / 59071
# test triplet 50100 / 59071
# test triplet 50200 / 59071
# test triplet 50300 / 59071
# test triplet 2500 / 59071
# test triplet 2600 / 59071
# test triplet 2700 / 59071
# test triplet 2800 / 59071
# test triplet 2900 / 59071
# test triplet 3000 / 59071
# test triplet 3100 / 59071
# test triplet 3200 / 59071
# test triplet 3300 / 59071
# test triplet 3400 / 59071
# test triplet 3500 / 59071
# test triplet 3600 / 59071
# test triplet 3700 / 59071
# test triplet 3800 / 59071
# test triplet 3900 / 59071
# test triplet 4000 / 59071
# test triplet 4100 / 59071
# test triplet 4200 / 59071
# test triplet 4300 / 59071
# test triplet 4400 / 59071
# test triplet 4500 / 59071
# test triplet 4600 / 59071
# test triplet 4700 / 59071
# test triplet 4800 / 59071
# test triplet 4900 / 59071
# test triplet 5000 / 59071
# test triplet 5100 / 59071
# test triplet 5200 / 59071
# test triplet 5300 / 59071
# test triplet 5400 / 59071
# test triplet 5500 / 59071
# test triplet 5600 / 59071
# test triplet 5700 / 59071
# test triplet 5800 / 59071
# test triplet 5900 / 59071
# test triplet 6000 / 59071
# test triplet 6100 / 59071
# test triplet 6200 / 59071
# test triplet 6300 / 59071
# test triplet 6400 / 59071
# test triplet 6500 / 59071
# test triplet 6600 / 59071
# test triplet 6700 / 59071
# test triplet 6800 / 59071
# test triplet 6900 / 59071
# test triplet 7000 / 59071
# test triplet 7100 / 59071
# test triplet 7200 / 59071
# test triplet 7300 / 59071
# test triplet 7400 / 59071
# test triplet 7500 / 59071
# test triplet 7600 / 59071
# test triplet 7700 / 59071
# test triplet 7800 / 59071
# test triplet 7900 / 59071
# test triplet 8000 / 59071
# test triplet 8100 / 59071
# test triplet 8200 / 59071
# test triplet 8300 / 59071
# test triplet 8400 / 59071
# test triplet 8500 / 59071
# test triplet 8600 / 59071
# test triplet 8700 / 59071
# test triplet 8800 / 59071
# test triplet 8900 / 59071
# test triplet 9000 / 59071
# test triplet 9100 / 59071
# test triplet 9200 / 59071
# test triplet 9300 / 59071
# test triplet 9400 / 59071
# test triplet 9500 / 59071
# test triplet 9600 / 59071
# test triplet 9700 / 59071
# test triplet 9800 / 59071
# test triplet 9900 / 59071
# test triplet 10000 / 59071
# test triplet 10100 / 59071
# test triplet 10200 / 59071
# test triplet 10300 / 59071
# test triplet 10400 / 59071
# test triplet 10500 / 59071
# test triplet 10600 / 59071
# test triplet 10700 / 59071
# test triplet 10800 / 59071
# test triplet 10900 / 59071
# test triplet 11000 / 59071
# test triplet 11100 / 59071
# test triplet 11200 / 59071
# test triplet 11300 / 59071
# test triplet 11400 / 59071
# test triplet 11500 / 59071
# test triplet 11600 / 59071
# test triplet 11700 / 59071
# test triplet 11800 / 59071
# test triplet 11900 / 59071
# test triplet 12000 / 59071
# test triplet 12100 / 59071
# test triplet 12200 / 59071
# test triplet 12300 / 59071
# test triplet 12400 / 59071
# test triplet 12500 / 59071
# test triplet 12600 / 59071
# test triplet 12700 / 59071
# test triplet 12800 / 59071
# test triplet 12900 / 59071
# test triplet 13000 / 59071
# test triplet 13100 / 59071
# test triplet 13200 / 59071
# test triplet 13300 / 59071
# test triplet 13400 / 59071
# test triplet 13500 / 59071
# test triplet 13600 / 59071
# test triplet 13700 / 59071
# test triplet 13800 / 59071
# test triplet 13900 / 59071
# test triplet 14000 / 59071
# test triplet 14100 / 59071
# test triplet 14200 / 59071
# test triplet 14300 / 59071
# test triplet 14400 / 59071
# test triplet 14500 / 59071
# test triplet 14600 / 59071
# test triplet 14700 / 59071
# test triplet 14800 / 59071
# test triplet 14900 / 59071
# test triplet 15000 / 59071
# test triplet 15100 / 59071
# test triplet 15200 / 59071
# test triplet 15300 / 59071
# test triplet 15400 / 59071
# test triplet 15500 / 59071
# test triplet 15600 / 59071
# test triplet 15700 / 59071
# test triplet 15800 / 59071
# test triplet 15900 / 59071
# test triplet 16000 / 59071
# test triplet 16100 / 59071
# test triplet 16200 / 59071
# test triplet 16300 / 59071
# test triplet 16400 / 59071
# test triplet 16500 / 59071
# test triplet 16600 / 59071
# test triplet 16700 / 59071
# test triplet 16800 / 59071
# test triplet 16900 / 59071
# test triplet 17000 / 59071
# test triplet 17100 / 59071
# test triplet 17200 / 59071
# test triplet 17300 / 59071
# test triplet 17400 / 59071
# test triplet 17500 / 59071
# test triplet 17600 / 59071
# test triplet 17700 / 59071
# test triplet 17800 / 59071
# test triplet 17900 / 59071
# test triplet 18000 / 59071
# test triplet 18100 / 59071
# test triplet 18200 / 59071
# test triplet 18300 / 59071
# test triplet 18400 / 59071
# test triplet 18500 / 59071
# test triplet 18600 / 59071
# test triplet 18700 / 59071
# test triplet 18800 / 59071
# test triplet 18900 / 59071
# test triplet 19000 / 59071
# test triplet 19100 / 59071
# test triplet 19200 / 59071
# test triplet 19300 / 59071
# test triplet 19400 / 59071
# test triplet 19500 / 59071
# test triplet 19600 / 59071
# test triplet 19700 / 59071
# test triplet 19800 / 59071
# test triplet 19900 / 59071
# test triplet 20000 / 59071
# test triplet 20100 / 59071
# test triplet 20200 / 59071
# test triplet 20300 / 59071
# test triplet 20400 / 59071
# test triplet 20500 / 59071
# test triplet 20600 / 59071
# test triplet 20700 / 59071
# test triplet 20800 / 59071
# test triplet 20900 / 59071
# test triplet 21000 / 59071
# test triplet 21100 / 59071
# test triplet 21200 / 59071
# test triplet 21300 / 59071
# test triplet 21400 / 59071
# test triplet 21500 / 59071
# test triplet 21600 / 59071
# test triplet 21700 / 59071
# test triplet 21800 / 59071
# test triplet 21900 / 59071
# test triplet 22000 / 59071
# test triplet 22100 / 59071
# test triplet 22200 / 59071
# test triplet 22300 / 59071
# test triplet 22400 / 59071
# test triplet 22500 / 59071
# test triplet 22600 / 59071
# test triplet 22700 / 59071
# test triplet 22800 / 59071
# test triplet 22900 / 59071
# test triplet 23000 / 59071
# test triplet 23100 / 59071
# test triplet 23200 / 59071
# test triplet 23300 / 59071
# test triplet 23400 / 59071
# test triplet 23500 / 59071
# test triplet 23600 / 59071
# test triplet 23700 / 59071
# test triplet 23800 / 59071
# test triplet 23900 / 59071
# test triplet 24000 / 59071
# test triplet 24100 / 59071
# test triplet 24200 / 59071
# test triplet 24300 / 59071
# test triplet 24400 / 59071
# test triplet 24500 / 59071
# test triplet 24600 / 59071
# test triplet 35800 / 59071
# test triplet 35900 / 59071
# test triplet 36000 / 59071
# test triplet 36100 / 59071
# test triplet 36200 / 59071
# test triplet 36300 / 59071
# test triplet 36400 / 59071
# test triplet 36500 / 59071
# test triplet 36600 / 59071
# test triplet 36700 / 59071
# test triplet 36800 / 59071
# test triplet 36900 / 59071
# test triplet 37000 / 59071
# test triplet 37100 / 59071
# test triplet 37200 / 59071
# test triplet 37300 / 59071
# test triplet 37400 / 59071
# test triplet 37500 / 59071
# test triplet 37600 / 59071
# test triplet 37700 / 59071
# test triplet 37800 / 59071
# test triplet 37900 / 59071
# test triplet 38000 / 59071
# test triplet 38100 / 59071
# test triplet 38200 / 59071
# test triplet 38300 / 59071
# test triplet 38400 / 59071
# test triplet 38500 / 59071
# test triplet 38600 / 59071
# test triplet 38700 / 59071
# test triplet 38800 / 59071
# test triplet 38900 / 59071
# test triplet 39000 / 59071
# test triplet 39100 / 59071
# test triplet 39200 / 59071
# test triplet 39300 / 59071
# test triplet 39400 / 59071
# test triplet 39500 / 59071
# test triplet 39600 / 59071
# test triplet 39700 / 59071
# test triplet 39800 / 59071
# test triplet 39900 / 59071
# test triplet 40000 / 59071
# test triplet 40100 / 59071
# test triplet 40200 / 59071
# test triplet 40300 / 59071
# test triplet 40400 / 59071
# test triplet 40500 / 59071
# test triplet 40600 / 59071
# test triplet 40700 / 59071
# test triplet 40800 / 59071
# test triplet 40900 / 59071
# test triplet 41000 / 59071
# test triplet 41100 / 59071
# test triplet 41200 / 59071
# test triplet 41300 / 59071
# test triplet 41400 / 59071
# test triplet 41500 / 59071
# test triplet 41600 / 59071
# test triplet 41700 / 59071
# test triplet 41800 / 59071
# test triplet 41900 / 59071
# test triplet 42000 / 59071
# test triplet 42100 / 59071
# test triplet 42200 / 59071
# test triplet 42300 / 59071
# test triplet 42400 / 59071
# test triplet 42500 / 59071
# test triplet 42600 / 59071
# test triplet 42700 / 59071
# test triplet 42800 / 59071
# test triplet 42900 / 59071
# test triplet 43000 / 59071
# test triplet 43100 / 59071
# test triplet 43200 / 59071
# test triplet 43300 / 59071
# test triplet 43400 / 59071
# test triplet 43500 / 59071
# test triplet 43600 / 59071
# test triplet 43700 / 59071
# test triplet 43800 / 59071
# test triplet 43900 / 59071
# test triplet 44000 / 59071
# test triplet 44100 / 59071
# test triplet 44200 / 59071
# test triplet 44300 / 59071
# test triplet 44400 / 59071
# test triplet 44500 / 59071
# test triplet 44600 / 59071
# test triplet 44700 / 59071
# test triplet 44800 / 59071
# test triplet 44900 / 59071
# test triplet 45000 / 59071
# test triplet 45100 / 59071
# test triplet 45200 / 59071
# test triplet 45300 / 59071
# test triplet 45400 / 59071
# test triplet 45500 / 59071
# test triplet 45600 / 59071
# test triplet 45700 / 59071
# test triplet 45800 / 59071
# test triplet 45900 / 59071
# test triplet 46000 / 59071
# test triplet 46100 / 59071
# test triplet 46200 / 59071
# test triplet 46300 / 59071
# test triplet 46400 / 59071
# test triplet 46500 / 59071
# test triplet 46600 / 59071
# test triplet 46700 / 59071
# test triplet 46800 / 59071
# test triplet 46900 / 59071
# test triplet 58100 / 59071
# test triplet 58200 / 59071
# test triplet 58300 / 59071
# test triplet 58400 / 59071
# test triplet 58500 / 59071
# test triplet 58600 / 59071
# test triplet 58700 / 59071
# test triplet 58800 / 59071
# test triplet 58900 / 59071
# test triplet 59000 / 59071
# MRR (filtered): 0.124467
# Hits (filtered) @ 1: 0.072887
# Hits (filtered) @ 3: 0.126356
# Hits (filtered) @ 10: 0.223629
# training done
# Mean forward time: 0.085046s
# Mean Backward time: 0.165326s

# %%
print("\nstart testing:")
checkpoint = torch.load(model_state_file)
if use_cuda:
    model.cpu()
model.eval()
model.load_state_dict(checkpoint['state_dict'])
print("Using best epoch: {}".format(checkpoint['epoch']))
embed = model(test_graph, test_node_id, test_rel, test_norm)
calc_mrr(embed, model.w_relation, torch.LongTensor(train_data), valid_data, test_data, hits=[1, 3, 10], eval_bz=eval_batch_size, eval_p=eval_protocol)
# Out:
# triplet 44200 / 59071
# test triplet 44300 / 59071
# test triplet 44400 / 59071
# test triplet 44500 / 59071
# test triplet 44600 / 59071
# test triplet 44700 / 59071
# test triplet 44800 / 59071
# test triplet 44900 / 59071
# test triplet 45000 / 59071
# test triplet 45100 / 59071
# test triplet 45200 / 59071
# test triplet 45300 / 59071
# test triplet 45400 / 59071
# test triplet 45500 / 59071
# test triplet 45600 / 59071
# test triplet 45700 / 59071
# test triplet 45800 / 59071
# test triplet 45900 / 59071
# test triplet 46000 / 59071
# test triplet 46100 / 59071
# test triplet 46200 / 59071
# test triplet 46300 / 59071
# test triplet 46400 / 59071
# test triplet 46500 / 59071
# test triplet 46600 / 59071
# test triplet 46700 / 59071
# test triplet 46800 / 59071
# test triplet 46900 / 59071
# test triplet 47000 / 59071
# test triplet 47100 / 59071
# test triplet 47200 / 59071
# test triplet 47300 / 59071
# test triplet 47400 / 59071
# test triplet 47500 / 59071
# test triplet 47600 / 59071
# test triplet 47700 / 59071
# test triplet 47800 / 59071
# test triplet 47900 / 59071
# test triplet 48000 / 59071
# test triplet 48100 / 59071
# test triplet 48200 / 59071
# test triplet 48300 / 59071
# test triplet 48400 / 59071
# test triplet 48500 / 59071
# test triplet 48600 / 59071
# test triplet 48700 / 59071
# test triplet 48800 / 59071
# test triplet 48900 / 59071
# test triplet 49000 / 59071
# test triplet 49100 / 59071
# test triplet 49200 / 59071
# test triplet 49300 / 59071
# test triplet 49400 / 59071
# test triplet 49500 / 59071
# test triplet 49600 / 59071
# test triplet 49700 / 59071
# test triplet 49800 / 59071
# test triplet 49900 / 59071
# test triplet 50000 / 59071
# test triplet 50100 / 59071
# test triplet 50200 / 59071
# test triplet 50300 / 59071
# test triplet 50400 / 59071
# test triplet 50500 / 59071
# test triplet 50600 / 59071
# test triplet 50700 / 59071
# test triplet 50800 / 59071
# test triplet 50900 / 59071
# test triplet 51000 / 59071
# test triplet 51100 / 59071
# test triplet 51200 / 59071
# test triplet 51300 / 59071
# test triplet 51400 / 59071
# test triplet 51500 / 59071
# test triplet 51600 / 59071
# test triplet 51700 / 59071
# test triplet 51800 / 59071
# test triplet 51900 / 59071
# test triplet 4100 / 59071
# test triplet 4200 / 59071
# test triplet 4300 / 59071
# test triplet 4400 / 59071
# test triplet 4500 / 59071
# test triplet 4600 / 59071
# test triplet 4700 / 59071
# test triplet 4800 / 59071
# test triplet 4900 / 59071
# test triplet 5000 / 59071
# test triplet 5100 / 59071
# test triplet 5200 / 59071
# test triplet 5300 / 59071
# test triplet 5400 / 59071
# test triplet 5500 / 59071
# test triplet 5600 / 59071
# test triplet 5700 / 59071
# test triplet 5800 / 59071
# test triplet 5900 / 59071
# test triplet 6000 / 59071
# test triplet 6100 / 59071
# test triplet 6200 / 59071
# test triplet 6300 / 59071
# test triplet 6400 / 59071
# test triplet 6500 / 59071
# test triplet 6600 / 59071
# test triplet 6700 / 59071
# test triplet 6800 / 59071
# test triplet 6900 / 59071
# test triplet 7000 / 59071
# test triplet 7100 / 59071
# test triplet 7200 / 59071
# test triplet 7300 / 59071
# test triplet 7400 / 59071
# test triplet 7500 / 59071
# test triplet 7600 / 59071
# test triplet 7700 / 59071
# test triplet 7800 / 59071
# test triplet 7900 / 59071
# test triplet 8000 / 59071
# test triplet 8100 / 59071
# test triplet 8200 / 59071
# test triplet 8300 / 59071
# test triplet 8400 / 59071
# test triplet 8500 / 59071
# test triplet 8600 / 59071
# test triplet 8700 / 59071
# test triplet 8800 / 59071
# test triplet 8900 / 59071
# test triplet 9000 / 59071
# test triplet 9100 / 59071
# test triplet 9200 / 59071
# test triplet 9300 / 59071
# test triplet 9400 / 59071
# test triplet 9500 / 59071
# test triplet 9600 / 59071
# test triplet 9700 / 59071
# test triplet 9800 / 59071
# test triplet 9900 / 59071
# test triplet 10000 / 59071
# test triplet 10100 / 59071
# test triplet 10200 / 59071
# test triplet 10300 / 59071
# test triplet 10400 / 59071
# test triplet 10500 / 59071
# test triplet 10600 / 59071
# test triplet 10700 / 59071
# test triplet 10800 / 59071
# test triplet 10900 / 59071
# test triplet 11000 / 59071
# test triplet 11100 / 59071
# test triplet 11200 / 59071
# test triplet 11300 / 59071
# test triplet 11400 / 59071
# test triplet 11500 / 59071
# test triplet 11600 / 59071
# test triplet 11700 / 59071
# test triplet 11800 / 59071
# test triplet 11900 / 59071
# test triplet 12000 / 59071
# test triplet 12100 / 59071
# test triplet 12200 / 59071
# test triplet 12300 / 59071
# test triplet 12400 / 59071
# test triplet 12500 / 59071
# test triplet 12600 / 59071
# test triplet 12700 / 59071
# test triplet 12800 / 59071
# test triplet 12900 / 59071
# test triplet 13000 / 59071
# test triplet 13100 / 59071
# test triplet 13200 / 59071
# test triplet 13300 / 59071
# test triplet 13400 / 59071
# test triplet 13500 / 59071
# test triplet 13600 / 59071
# test triplet 13700 / 59071
# test triplet 13800 / 59071
# test triplet 13900 / 59071
# test triplet 14000 / 59071
# test triplet 14100 / 59071
# test triplet 14200 / 59071
# test triplet 14300 / 59071
# test triplet 14400 / 59071
# test triplet 14500 / 59071
# test triplet 14600 / 59071
# test triplet 14700 / 59071
# test triplet 14800 / 59071
# test triplet 14900 / 59071
# test triplet 15000 / 59071
# test triplet 15100 / 59071
# test triplet 15200 / 59071
# test triplet 15300 / 59071
# test triplet 15400 / 59071
# test triplet 15500 / 59071
# test triplet 15600 / 59071
# test triplet 15700 / 59071
# test triplet 15800 / 59071
# test triplet 15900 / 59071
# test triplet 16000 / 59071
# test triplet 16100 / 59071
# test triplet 16200 / 59071
# test triplet 16300 / 59071
# test triplet 16400 / 59071
# test triplet 16500 / 59071
# test triplet 16600 / 59071
# test triplet 16700 / 59071
# test triplet 16800 / 59071
# test triplet 16900 / 59071
# test triplet 17000 / 59071
# test triplet 17100 / 59071
# test triplet 17200 / 59071
# test triplet 17300 / 59071
# test triplet 17400 / 59071
# test triplet 17500 / 59071
# test triplet 17600 / 59071
# test triplet 17700 / 59071
# test triplet 17800 / 59071
# test triplet 17900 / 59071
# test triplet 18000 / 59071
# test triplet 18100 / 59071
# test triplet 18200 / 59071
# test triplet 18300 / 59071
# test triplet 18400 / 59071
# test triplet 18500 / 59071
# test triplet 18600 / 59071
# test triplet 18700 / 59071
# test triplet 18800 / 59071
# test triplet 18900 / 59071
# test triplet 19000 / 59071
# test triplet 19100 / 59071
# test triplet 19200 / 59071
# test triplet 19300 / 59071
# test triplet 19400 / 59071
# test triplet 19500 / 59071
# test triplet 19600 / 59071
# test triplet 19700 / 59071
# test triplet 19800 / 59071
# test triplet 19900 / 59071
# test triplet 20000 / 59071
# test triplet 20100 / 59071
# test triplet 20200 / 59071
# test triplet 20300 / 59071
# test triplet 20400 / 59071
# test triplet 20500 / 59071
# test triplet 20600 / 59071
# test triplet 20700 / 59071
# test triplet 20800 / 59071
# test triplet 20900 / 59071
# test triplet 21000 / 59071
# test triplet 21100 / 59071
# test triplet 21200 / 59071
# test triplet 21300 / 59071
# test triplet 21400 / 59071
# test triplet 21500 / 59071
# test triplet 21600 / 59071
# test triplet 21700 / 59071
# test triplet 21800 / 59071
# test triplet 21900 / 59071
# test triplet 22000 / 59071
# test triplet 22100 / 59071
# test triplet 22200 / 59071
# test triplet 22300 / 59071
# test triplet 22400 / 59071
# test triplet 22500 / 59071
# test triplet 22600 / 59071
# test triplet 22700 / 59071
# test triplet 22800 / 59071
# test triplet 22900 / 59071
# test triplet 23000 / 59071
# test triplet 23100 / 59071
# test triplet 23200 / 59071
# test triplet 23300 / 59071
# test triplet 23400 / 59071
# test triplet 23500 / 59071
# test triplet 23600 / 59071
# test triplet 23700 / 59071
# test triplet 23800 / 59071
# test triplet 23900 / 59071
# test triplet 24000 / 59071
# test triplet 24100 / 59071
# test triplet 24200 / 59071
# test triplet 24300 / 59071
# test triplet 24400 / 59071
# test triplet 24500 / 59071
# test triplet 24600 / 59071
# test triplet 24700 / 59071
# test triplet 24800 / 59071
# test triplet 24900 / 59071
# test triplet 25000 / 59071
# test triplet 25100 / 59071
# test triplet 25200 / 59071
# test triplet 25300 / 59071
# test triplet 25400 / 59071
# test triplet 25500 / 59071
# test triplet 25600 / 59071
# test triplet 25700 / 59071
# test triplet 25800 / 59071
# test triplet 25900 / 59071
# test triplet 26000 / 59071
# test triplet 26100 / 59071
# test triplet 26200 / 59071
# test triplet 37500 / 59071
# test triplet 37600 / 59071
# test triplet 37700 / 59071
# test triplet 37800 / 59071
# test triplet 37900 / 59071
# test triplet 38000 / 59071
# test triplet 38100 / 59071
# test triplet 38200 / 59071
# test triplet 38300 / 59071
# test triplet 38400 / 59071
# test triplet 38500 / 59071
# test triplet 38600 / 59071
# test triplet 38700 / 59071
# test triplet 38800 / 59071
# test triplet 38900 / 59071
# test triplet 39000 / 59071
# test triplet 39100 / 59071
# test triplet 39200 / 59071
# test triplet 39300 / 59071
# test triplet 39400 / 59071
# test triplet 39500 / 59071
# test triplet 39600 / 59071
# test triplet 39700 / 59071
# test triplet 39800 / 59071
# test triplet 39900 / 59071
# test triplet 40000 / 59071
# test triplet 40100 / 59071
# test triplet 40200 / 59071
# test triplet 40300 / 59071
# test triplet 40400 / 59071
# test triplet 40500 / 59071
# test triplet 40600 / 59071
# test triplet 40700 / 59071
# test triplet 40800 / 59071
# test triplet 40900 / 59071
# test triplet 41000 / 59071
# test triplet 41100 / 59071
# test triplet 41200 / 59071
# test triplet 41300 / 59071
# test triplet 41400 / 59071
# test triplet 41500 / 59071
# test triplet 41600 / 59071
# test triplet 41700 / 59071
# test triplet 41800 / 59071
# test triplet 41900 / 59071
# test triplet 42000 / 59071
# test triplet 42100 / 59071
# test triplet 42200 / 59071
# test triplet 42300 / 59071
# test triplet 42400 / 59071
# test triplet 42500 / 59071
# test triplet 42600 / 59071
# test triplet 42700 / 59071
# test triplet 42800 / 59071
# test triplet 42900 / 59071
# test triplet 43000 / 59071
# test triplet 43100 / 59071
# test triplet 43200 / 59071
# test triplet 43300 / 59071
# test triplet 43400 / 59071
# test triplet 43500 / 59071
# test triplet 43600 / 59071
# test triplet 43700 / 59071
# test triplet 43800 / 59071
# test triplet 43900 / 59071
# test triplet 44000 / 59071
# test triplet 44100 / 59071
# test triplet 44200 / 59071
# test triplet 44300 / 59071
# test triplet 44400 / 59071
# test triplet 44500 / 59071
# test triplet 44600 / 59071
# test triplet 44700 / 59071
# test triplet 44800 / 59071
# test triplet 44900 / 59071
# test triplet 45000 / 59071
# test triplet 45100 / 59071
# test triplet 45200 / 59071
# test triplet 45300 / 59071
# test triplet 45400 / 59071
# test triplet 45500 / 59071
# test triplet 45600 / 59071
# test triplet 45700 / 59071
# test triplet 45800 / 59071
# test triplet 45900 / 59071
# test triplet 46000 / 59071
# test triplet 46100 / 59071
# test triplet 46200 / 59071
# test triplet 46300 / 59071
# test triplet 46400 / 59071
# test triplet 46500 / 59071
# test triplet 46600 / 59071
# test triplet 46700 / 59071
# test triplet 46800 / 59071
# test triplet 46900 / 59071
# test triplet 47000 / 59071
# test triplet 47100 / 59071
# test triplet 47200 / 59071
# test triplet 47300 / 59071
# test triplet 47400 / 59071
# test triplet 47500 / 59071
# test triplet 47600 / 59071
# test triplet 47700 / 59071
# test triplet 47800 / 59071
# test triplet 47900 / 59071
# test triplet 48000 / 59071
# test triplet 48100 / 59071
# test triplet 48200 / 59071
# test triplet 48300 / 59071
# test triplet 48400 / 59071
# test triplet 48500 / 59071
# test triplet 48600 / 59071
# test triplet 48700 / 59071
# test triplet 48800 / 59071
# test triplet 48900 / 59071
# test triplet 49000 / 59071
# test triplet 49100 / 59071
# test triplet 49200 / 59071
# test triplet 49300 / 59071
# test triplet 49400 / 59071
# test triplet 49500 / 59071
# test triplet 49600 / 59071
# test triplet 49700 / 59071
# test triplet 49800 / 59071
# test triplet 49900 / 59071
# test triplet 50000 / 59071
# test triplet 50100 / 59071
# test triplet 50200 / 59071
# test triplet 50300 / 59071
# test triplet 50400 / 59071
# test triplet 50500 / 59071
# test triplet 50600 / 59071
# test triplet 50700 / 59071
# test triplet 50800 / 59071
# test triplet 50900 / 59071
# test triplet 51000 / 59071
# test triplet 51100 / 59071
# test triplet 51200 / 59071
# test triplet 51300 / 59071
# test triplet 51400 / 59071
# test triplet 51500 / 59071
# test triplet 51600 / 59071
# test triplet 51700 / 59071
# test triplet 51800 / 59071
# test triplet 51900 / 59071
# test triplet 52000 / 59071
# test triplet 52100 / 59071
# test triplet 52200 / 59071
# test triplet 52300 / 59071
# test triplet 52400 / 59071
# test triplet 52500 / 59071
# test triplet 52600 / 59071
# test triplet 52700 / 59071
# test triplet 52800 / 59071
# test triplet 52900 / 59071
# test triplet 53000 / 59071
# test triplet 53100 / 59071
# test triplet 53200 / 59071
# test triplet 53300 / 59071
# test triplet 53400 / 59071
# test triplet 53500 / 59071
# test triplet 53600 / 59071
# test triplet 53700 / 59071
# test triplet 53800 / 59071
# test triplet 53900 / 59071
# test triplet 54000 / 59071
# test triplet 54100 / 59071
# test triplet 54200 / 59071
# test triplet 54300 / 59071
# test triplet 54400 / 59071
# test triplet 54500 / 59071
# test triplet 54600 / 59071
# test triplet 54700 / 59071
# test triplet 54800 / 59071
# test triplet 54900 / 59071
# test triplet 55000 / 59071
# test triplet 55100 / 59071
# test triplet 55200 / 59071
# test triplet 55300 / 59071
# test triplet 55400 / 59071
# test triplet 55500 / 59071
# test triplet 55600 / 59071
# test triplet 55700 / 59071
# test triplet 55800 / 59071
# test triplet 55900 / 59071
# test triplet 56000 / 59071
# test triplet 56100 / 59071
# test triplet 56200 / 59071
# test triplet 56300 / 59071
# test triplet 56400 / 59071
# test triplet 56500 / 59071
# test triplet 56600 / 59071
# test triplet 56700 / 59071
# test triplet 56800 / 59071
# test triplet 56900 / 59071
# test triplet 57000 / 59071
# test triplet 57100 / 59071
# test triplet 57200 / 59071
# test triplet 57300 / 59071
# test triplet 57400 / 59071
# test triplet 57500 / 59071
# test triplet 57600 / 59071
# test triplet 57700 / 59071
# test triplet 57800 / 59071
# test triplet 57900 / 59071
# test triplet 58000 / 59071
# test triplet 58100 / 59071
# test triplet 58200 / 59071
# test triplet 58300 / 59071
# test triplet 58400 / 59071
# test triplet 58500 / 59071
# test triplet 58600 / 59071
# test triplet 58700 / 59071
# test triplet 58800 / 59071
# test triplet 58900 / 59071
# test triplet 59000 / 59071
# MRR (filtered): 0.226040
# Hits (filtered) @ 1: 0.135185
# Hits (filtered) @ 3: 0.247431
# Hits (filtered) @ 10: 0.413181
# 0.2260395586490631
